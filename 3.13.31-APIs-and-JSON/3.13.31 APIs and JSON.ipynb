# %% [markdown]
# # 3.13.31 APIs and JSON

# %% [markdown]
# ### What is an API

# %% [markdown]
# An API, acronym for **Application Programming Interface**, is simply a software interface that **allows two applications to talk to each other**. Unlike a user interface, which connects a computer to a person, an application programming interface connects computers or pieces of software to each other. Although it is not meant to be used directly by the end user, data analysts and data scientists may use and test it directly before implementing it into their program/analysis.

# %% [markdown]
# <img src="img/what-is-api.png" width="600">

# %% [markdown]
# ### API Analogy
#
# Imagine that you're the owner of a store and you're on holiday at the beach. Although you should be relaxing, you're concerned about your business, so you instruct your friend to call the store at the end of every day and ask how many customers came and purchased something and then write it down on a blackboard next to your beachbed.
#
# This would be a real-world analogy of how an API works:
#
# - the two computers or pieces of software are the blackboard on your end (usually a browser, web app or script) and the store on the other side (usually a web server/database)
# - your friend is the intermediary who is doing the work of the API in connecting the two:
#     - he sends a request
#     - waits for a result
#     - then writes the result on the board
# - notice that you are not phisically making the request, you have instructed your friend, just like you write instructions for your program

# %% [markdown]
# ### API example
#
# You could write a script that asks the end user for a city name and, using a Google Maps API, returns the latitude and longitude coordinates of that city. Let's see how this process would work:
#
# - The end user starts the program, the program asks the user for a city name, which he enters in the prompt box
# - The program receives the city name in input and, via the Google Maps API, sends a request to Google's web server
# - Google's web server receives the request and queries its database to find the relative result
# - Meanwhile, the API is waiting for this result
# - once the web server returns the result, the API sends it back to the requesting program (the one you wrote)
# - the resulting latitude and longitude coordinates are then showed to the end user

# %% [markdown]
# Although there are [different types of APIs](https://en.wikipedia.org/wiki/API#Usage), we will focus on Web APIs. These are programs that use an internet address (like a URL), to provide access to their services.

# %% [markdown]
# ### Your first API call
#
# Let's look at a practical case. The city of Milan has a rich [Open Data portal](https://dati.comune.milano.it/) where you can access its data in several ways, namely by:
# - downloading a file
# - retrieving the data via an API call
#
# When we say "API call", we mean that we are **sending a request** via the API (just like we were sending our friend to phone the store in our previous analogy).

# %% [markdown]
# For example, [at this page](https://dati.comune.milano.it/dataset/ds1573-gas-erogato-a2a-totale-giornaliero) we can find the **daily total gas delivered by A2A** (an italian energy provider) in cubic meters. As you can see, there are **two data formats** available, csv and json.
#
# If we click on the csv option, we are redirected to [this page](https://dati.comune.milano.it/dataset/ds1573-gas-erogato-a2a-totale-giornaliero/resource/dbd7417a-41e8-4097-a1c4-67094983bab1), where we can **see the data in a table** and we can either download the data on our computer (see the red button that says "Download") in a specified format (csv, tsv, json or xml) or we can **retrieve the data using their API** (see the green button that says "Data API").
#
# If you **click on the green button** that says `Data API`, a pop-up will be opened and you'll be able to see the URL that can be used to perform the API call *(note: this is also known as the [API endpoint](https://kinsta.com/knowledgebase/api-endpoint/#understanding-api-endpoints))* as well as some examples to get you started. For instance, if you **copy the following URL and paste it in your browser**, you will see the result of the API call in your browser, showing you the first 5 records of the data you were trying to retrieve ([click here](https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=5) to try it yourself!):
#
#     https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=5

# %% [markdown]
# Now, before we proceed any further, there are **a couple of observations** to be made:
# 1. The result we're obtaining looks a little messy... what are all those curly brackets?
# 2. Didn't we say that APIs are not meant to be used directly by the end user?
#
# Let's start by addressing the first point.

# %% [markdown]
# ### JSON

# %% [markdown]
# The strange, messy format of the result from our API call is called **JSON**, which is an acronym that stands for **JavaScript Object Notation**.
#
# According to [Wikipedia](https://en.wikipedia.org/wiki/JSON), *it is an open standard file format and data interchange format that uses human-readable text to store and transmit data objects consisting of attribute–value pairs and arrays*.
#
# Let's unpack the previous sentence:
# - it's a **file format** (just like a .csv file)
# - it **stores data**
# - the data is stored in **attribute-value** pairs
#
# So, it's just another way of storing data, like a csv or a text file, but it stores it using a method that should be familiar to you: the attribute-value pair works just like the key-value pairs from Python's dictionaries that we have seen at the beginning of this Module.

# %% [markdown]
# Now, the Wikipedia definition said also that the contents of the JSON is human readable and, looking at the API result, one could understandably argue against that statement. However, if we copy that result and paste it in a **JSON formatter** like [this one](https://jsonformatter.org/), you will see that **its readability improves** quite dramatically. Check out the example below to get a better idea of this particular data format:
#
# <img src="img/json.png" width="900">
#
# Although to a human it is not as readable as a csv file, its **nested hierarchical structure** allows you to include all kind of metadata next to the data itself. It takes time and practice to get used to this data format, so don't get discouraged if you're finding it harder than expected.
#
# Check out [this article](https://realpython.com/python-json/) to find out more about JSON data structures in relation to Python.

# %% [markdown]
# Let's now address the second observation from the previous section: APIs are meant to be used by a program, not to be typed in the address bar of a web browser. In the next section we'll look at how we can **make an API call in Python**.

# %% [markdown]
# ### API calls in Python

# %% [markdown]
# #### City of Milan API

# %% [markdown]
# Now we have all the necessary pieces to get started and make our first API call in Python. To do that, we'll need to load the `requests` [library](https://requests.readthedocs.io/en/latest/), whose goal is to make **HTTP requests in Python** simpler and more human-friendly (as stated also in the tagline of the library's logo).

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import requests

# %%
# save the URL string (without the limit=5 parameter) to a "url" object
url = 'https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1'
#url = 'https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=1000'

# %% [markdown]
# The **GET** [HTTP method](https://www.w3schools.com/tags/ref_httpmethods.asp) allows you to request data from a specified resource or server. In the `requests` library this can be achieved via the `get()` function:

# %%
# make the HTTP request
r = requests.get(url)

# %% [markdown]
# Every time you send a request, you will expect some data in return. Together with your data, **you will also receive a status code**, telling you whether the request was successful. Make sure to always check the status of your request via the `.status_code` attribute and to **verify the meaning** of that status. A status of 200 means that the request was successful, check [this page](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes#1xx_informational_response) for a complete list of statuses.

# %%
# check the status code of your HTTP request
r.status_code
# Out:
# 200

# %% [markdown]
# If you're dealing with json data, you can **explore the contents of your result** using the `.json` attribute:

# %%
r.json()
# Out:
# {'help': 'https://dati.comune.milano.it/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'resource_id': 'dbd7417a-41e8-4097-a1c4-67094983bab1',
#   'fields': [{'type': 'int', 'id': '_id'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'numeric',
#     'id': 'Anno'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'timestamp',
#     'id': 'Data'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'text',
#     'id': 'Giorno'},
#    {'info': {'notes': '', 'type_override': 'numeric', 'label': ''},
#     'type': 'numeric',
#     'id': 'Totale (Smc)'}],
#   'records_format': 'objects',
#   'records': [{'_id': 1,
#     'Anno': 2019,
#     'Data': '2019-01-01T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6603230},
#    {'_id': 2,
#     'Anno': 2019,
#     'Data': '2019-01-02T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6579016},
#    {'_id': 3,
#     'Anno': 2019,
#     'Data': '2019-01-03T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7115704},
#    {'_id': 4,
#     'Anno': 2019,
#     'Data': '2019-01-04T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7650062},
#    {'_id': 5,
#     'Anno': 2019,
#     'Data': '2019-01-05T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7471068},
#    {'_id': 6,
#     'Anno': 2019,
#     'Data': '2019-01-06T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6764308},
#    {'_id': 7,
#     'Anno': 2019,
#     'Data': '2019-01-07T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7406714},
#    {'_id': 8,
#     'Anno': 2019,
#     'Data': '2019-01-08T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7697269},
#    {'_id': 9,
#     'Anno': 2019,
#     'Data': '2019-01-09T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7289985},
#    {'_id': 10,
#     'Anno': 2019,
#     'Data': '2019-01-10T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6942742},
#    {'_id': 11,
#     'Anno': 2019,
#     'Data': '2019-01-11T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7330613},
#    {'_id': 12,
#     'Anno': 2019,
#     'Data': '2019-01-12T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7093254},
#    {'_id': 13,
#     'Anno': 2019,
#     'Data': '2019-01-13T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6839856},
#    {'_id': 14,
#     'Anno': 2019,
#     'Data': '2019-01-14T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6152034},
#    {'_id': 15,
#     'Anno': 2019,
#     'Data': '2019-01-15T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6340289},
#    {'_id': 16,
#     'Anno': 2019,
#     'Data': '2019-01-16T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6186696},
#    {'_id': 17,
#     'Anno': 2019,
#     'Data': '2019-01-17T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6469788},
#    {'_id': 18,
#     'Anno': 2019,
#     'Data': '2019-01-18T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6808083},
#    {'_id': 19,
#     'Anno': 2019,
#     'Data': '2019-01-19T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6641610},
#    {'_id': 20,
#     'Anno': 2019,
#     'Data': '2019-01-20T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6932744},
#    {'_id': 21,
#     'Anno': 2019,
#     'Data': '2019-01-21T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7580166},
#    {'_id': 22,
#     'Anno': 2019,
#     'Data': '2019-01-22T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7743969},
#    {'_id': 23,
#     'Anno': 2019,
#     'Data': '2019-01-23T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 8174702},
#    {'_id': 24,
#     'Anno': 2019,
#     'Data': '2019-01-24T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7846440},
#    {'_id': 25,
#     'Anno': 2019,
#     'Data': '2019-01-25T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7846087},
#    {'_id': 26,
#     'Anno': 2019,
#     'Data': '2019-01-26T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7392830},
#    {'_id': 27,
#     'Anno': 2019,
#     'Data': '2019-01-27T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 7616016},
#    {'_id': 28,
#     'Anno': 2019,
#     'Data': '2019-01-28T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7553369},
#    {'_id': 29,
#     'Anno': 2019,
#     'Data': '2019-01-29T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7524599},
#    {'_id': 30,
#     'Anno': 2019,
#     'Data': '2019-01-30T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7848960},
#    {'_id': 31,
#     'Anno': 2019,
#     'Data': '2019-01-31T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 8073122},
#    {'_id': 32,
#     'Anno': 2019,
#     'Data': '2019-02-01T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 8861184},
#    {'_id': 33,
#     'Anno': 2019,
#     'Data': '2019-02-02T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 8078085},
#    {'_id': 34,
#     'Anno': 2019,
#     'Data': '2019-02-03T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 7717585},
#    {'_id': 35,
#     'Anno': 2019,
#     'Data': '2019-02-04T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7618516},
#    {'_id': 36,
#     'Anno': 2019,
#     'Data': '2019-02-05T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7617265},
#    {'_id': 37,
#     'Anno': 2019,
#     'Data': '2019-02-06T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7457558},
#    {'_id': 38,
#     'Anno': 2019,
#     'Data': '2019-02-07T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7798382},
#    {'_id': 39,
#     'Anno': 2019,
#     'Data': '2019-02-08T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7245421},
#    {'_id': 40,
#     'Anno': 2019,
#     'Data': '2019-02-09T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6542627},
#    {'_id': 41,
#     'Anno': 2019,
#     'Data': '2019-02-10T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6774689},
#    {'_id': 42,
#     'Anno': 2019,
#     'Data': '2019-02-11T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6925386},
#    {'_id': 43,
#     'Anno': 2019,
#     'Data': '2019-02-12T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6377350},
#    {'_id': 44,
#     'Anno': 2019,
#     'Data': '2019-02-13T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6535263},
#    {'_id': 45,
#     'Anno': 2019,
#     'Data': '2019-02-14T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6475077},
#    {'_id': 46,
#     'Anno': 2019,
#     'Data': '2019-02-15T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6093690},
#    {'_id': 47,
#     'Anno': 2019,
#     'Data': '2019-02-16T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5632209},
#    {'_id': 48,
#     'Anno': 2019,
#     'Data': '2019-02-17T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5452881},
#    {'_id': 49,
#     'Anno': 2019,
#     'Data': '2019-02-18T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5690448},
#    {'_id': 50,
#     'Anno': 2019,
#     'Data': '2019-02-19T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5665280},
#    {'_id': 51,
#     'Anno': 2019,
#     'Data': '2019-02-20T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5987828},
#    {'_id': 52,
#     'Anno': 2019,
#     'Data': '2019-02-21T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5730852},
#    {'_id': 53,
#     'Anno': 2019,
#     'Data': '2019-02-22T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5130655},
#    {'_id': 54,
#     'Anno': 2019,
#     'Data': '2019-02-23T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5951766},
#    {'_id': 55,
#     'Anno': 2019,
#     'Data': '2019-02-24T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6071045},
#    {'_id': 56,
#     'Anno': 2019,
#     'Data': '2019-02-25T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6026920},
#    {'_id': 57,
#     'Anno': 2019,
#     'Data': '2019-02-26T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5311908},
#    {'_id': 58,
#     'Anno': 2019,
#     'Data': '2019-02-27T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4665319},
#    {'_id': 59,
#     'Anno': 2019,
#     'Data': '2019-02-28T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4535871},
#    {'_id': 60,
#     'Anno': 2019,
#     'Data': '2019-03-01T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4470330},
#    {'_id': 61,
#     'Anno': 2019,
#     'Data': '2019-03-02T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 4251066},
#    {'_id': 62,
#     'Anno': 2019,
#     'Data': '2019-03-03T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4102244},
#    {'_id': 63,
#     'Anno': 2019,
#     'Data': '2019-03-04T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5304389},
#    {'_id': 64,
#     'Anno': 2019,
#     'Data': '2019-03-05T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4953319},
#    {'_id': 65,
#     'Anno': 2019,
#     'Data': '2019-03-06T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5008642},
#    {'_id': 66,
#     'Anno': 2019,
#     'Data': '2019-03-07T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4757596},
#    {'_id': 67,
#     'Anno': 2019,
#     'Data': '2019-03-08T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4295680},
#    {'_id': 68,
#     'Anno': 2019,
#     'Data': '2019-03-09T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3900886},
#    {'_id': 69,
#     'Anno': 2019,
#     'Data': '2019-03-10T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3836885},
#    {'_id': 70,
#     'Anno': 2019,
#     'Data': '2019-03-11T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4920139},
#    {'_id': 71,
#     'Anno': 2019,
#     'Data': '2019-03-12T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5144200},
#    {'_id': 72,
#     'Anno': 2019,
#     'Data': '2019-03-13T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5014575},
#    {'_id': 73,
#     'Anno': 2019,
#     'Data': '2019-03-14T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4881277},
#    {'_id': 74,
#     'Anno': 2019,
#     'Data': '2019-03-15T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4006985},
#    {'_id': 75,
#     'Anno': 2019,
#     'Data': '2019-03-16T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3283153},
#    {'_id': 76,
#     'Anno': 2019,
#     'Data': '2019-03-17T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3845431},
#    {'_id': 77,
#     'Anno': 2019,
#     'Data': '2019-03-18T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4375780},
#    {'_id': 78,
#     'Anno': 2019,
#     'Data': '2019-03-19T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4736615},
#    {'_id': 79,
#     'Anno': 2019,
#     'Data': '2019-03-20T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4777663},
#    {'_id': 80,
#     'Anno': 2019,
#     'Data': '2019-03-21T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4535466},
#    {'_id': 81,
#     'Anno': 2019,
#     'Data': '2019-03-22T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3946367},
#    {'_id': 82,
#     'Anno': 2019,
#     'Data': '2019-03-23T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3179729},
#    {'_id': 83,
#     'Anno': 2019,
#     'Data': '2019-03-24T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2763954},
#    {'_id': 84,
#     'Anno': 2019,
#     'Data': '2019-03-25T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2950514},
#    {'_id': 85,
#     'Anno': 2019,
#     'Data': '2019-03-26T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3753546},
#    {'_id': 86,
#     'Anno': 2019,
#     'Data': '2019-03-27T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3896804},
#    {'_id': 87,
#     'Anno': 2019,
#     'Data': '2019-03-28T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3999182},
#    {'_id': 88,
#     'Anno': 2019,
#     'Data': '2019-03-29T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3620750},
#    {'_id': 89,
#     'Anno': 2019,
#     'Data': '2019-03-30T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3280864},
#    {'_id': 90,
#     'Anno': 2019,
#     'Data': '2019-03-31T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2942129},
#    {'_id': 91,
#     'Anno': 2019,
#     'Data': '2019-04-01T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2872943},
#    {'_id': 92,
#     'Anno': 2019,
#     'Data': '2019-04-02T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2721134},
#    {'_id': 93,
#     'Anno': 2019,
#     'Data': '2019-04-03T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3640068},
#    {'_id': 94,
#     'Anno': 2019,
#     'Data': '2019-04-04T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4428823},
#    {'_id': 95,
#     'Anno': 2019,
#     'Data': '2019-04-05T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3972527},
#    {'_id': 96,
#     'Anno': 2019,
#     'Data': '2019-04-06T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3583492},
#    {'_id': 97,
#     'Anno': 2019,
#     'Data': '2019-04-07T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3999847},
#    {'_id': 98,
#     'Anno': 2019,
#     'Data': '2019-04-08T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3811880},
#    {'_id': 99,
#     'Anno': 2019,
#     'Data': '2019-04-09T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3296666},
#    {'_id': 100,
#     'Anno': 2019,
#     'Data': '2019-04-10T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3338065}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1',
#    'next': '/api/3/action/datastore_search?offset=100&resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1'},
#   'total': 731}}

# %% [markdown]
# We can verify that this JSON object is in fact interpreted by Python as a dictionary:

# %%
type(r.json())
# Out:
# dict

# %% [markdown]
# And, since it is a dictionary, it can be accessed as one by specifying its keys via the [ ] operator:

# %%
r.json()['result']['records']
# Out:
# [{'type': 'int', 'id': '_id'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'numeric',
#   'id': 'Anno'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'timestamp',
#   'id': 'Data'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'text',
#   'id': 'Giorno'},
#  {'info': {'notes': '', 'type_override': 'numeric', 'label': ''},
#   'type': 'numeric',
#   'id': 'Totale (Smc)'}]

# %% [markdown]
# In the cell above we sliced the dictionary until we reached the `fields` key, which is itself a list of dictionaries. Therefore, we can cycle through each dictionary in this list and print the `id` keys, whose values contain the column names of the data that we retrieved using the API: *

# %%
for el in r.json()['result']['fields']: 
    print(el['id'])
# Out:
# _id
# Anno
# Data
# Giorno
# Totale (Smc)

# %% [markdown]
# Luckily, we don't need to loop through nested dictionaries to get the data in a useful format. If we slice the JSON object at the `records` key, we can see that it is composed of a list of dictionaries (as many as there are rows in the original dataset), each containing a set of key-value pairs (one for each column in the dataset).

# %%
r.json()['result']['records'][0:3]
# Out:
# [{'_id': 1,
#   'Anno': 2019,
#   'Data': '2019-01-01T00:00:00',
#   'Giorno': 'Martedi',
#   'Totale (Smc)': 6603230},
#  {'_id': 2,
#   'Anno': 2019,
#   'Data': '2019-01-02T00:00:00',
#   'Giorno': 'Mercoledi',
#   'Totale (Smc)': 6579016},
#  {'_id': 3,
#   'Anno': 2019,
#   'Data': '2019-01-03T00:00:00',
#   'Giorno': 'Giovedi',
#   'Totale (Smc)': 7115704}]

# %%
len(r.json()['result']['records'])
# Out:
# 100

# %% [markdown]
# Thanks to `pandas`, we can build a DataFrame using its `from_dict()` function:

# %%
df = pd.DataFrame.from_dict(r.json()['result']['records'])
df
# Out:
#     _id  Anno                 Data     Giorno  Totale (Smc)
# 0     1  2019  2019-01-01T00:00:00    Martedi       6603230
# 1     2  2019  2019-01-02T00:00:00  Mercoledi       6579016
# 2     3  2019  2019-01-03T00:00:00    Giovedi       7115704
# 3     4  2019  2019-01-04T00:00:00    Venerdi       7650062
# 4     5  2019  2019-01-05T00:00:00     Sabato       7471068
# ..  ...   ...                  ...        ...           ...
# 95   96  2019  2019-04-06T00:00:00     Sabato       3583492
# 96   97  2019  2019-04-07T00:00:00   Domenica       3999847
# 97   98  2019  2019-04-08T00:00:00     Lunedi       3811880
# 98   99  2019  2019-04-09T00:00:00    Martedi       3296666
# 99  100  2019  2019-04-10T00:00:00  Mercoledi       3338065
#
# [100 rows x 5 columns]

# %% [markdown]
# Let's quickly convert the `Data` variable to a datetime type and plot the time series using `seaborn`:

# %%
df['Data'] = pd.to_datetime(df['Data'], format="%Y-%m-%d")

# %%
sns.set(rc={'figure.figsize':(13, 7)})   # change the figure size
sns.lineplot(x="Data", y="Totale (Smc)", data=df)
plt.show()

# %% [markdown]
# #### More public APIs

# %% [markdown]
# At [this web page](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/), you can find a long list of public APIs, meaning you can use them without the need to sign-up, create an account or authenticate to the service in order to access the unterlying data. To keep things nice and simple and allow you to practice more with APIs, let's look at that list and, for instance let's try the [Binance API](https://binance-docs.github.io/apidocs/spot/en/#introduction) example, which shows the endpoint to get some statistics on the [24hr Ticker Price Change](https://binance-docs.github.io/apidocs/spot/en/#24hr-ticker-price-change-statistics):

# %%
url_binance = 'https://api2.binance.com/api/v3/ticker/24hr'
bnc = requests.get(url_binance)

# %%
bnc.status_code

# %%
bnc.json()[0:3]
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '-0.00052200',
#   'priceChangePercent': '-0.954',
#   'weightedAvgPrice': '0.05465656',
#   'prevClosePrice': '0.05473300',
#   'lastPrice': '0.05421000',
#   'lastQty': '0.86750000',
#   'bidPrice': '0.05420800',
#   'bidQty': '8.79830000',
#   'askPrice': '0.05420900',
#   'askQty': '15.84020000',
#   'openPrice': '0.05473200',
#   'highPrice': '0.05559700',
#   'lowPrice': '0.05373800',
#   'volume': '240257.36420000',
#   'quoteVolume': '13131.64058701',
#   'openTime': 1655749304179,
#   'closeTime': 1655835704179,
#   'firstId': 350183160,
#   'lastId': 350451842,
#   'count': 268683},
#  {'symbol': 'LTCBTC',
#   'priceChange': '-0.00006900',
#   'priceChangePercent': '-2.654',
#   'weightedAvgPrice': '0.00254887',
#   'prevClosePrice': '0.00260100',
#   'lastPrice': '0.00253100',
#   'lastQty': '1.87000000',
#   'bidPrice': '0.00253100',
#   'bidQty': '10.55900000',
#   'askPrice': '0.00253200',
#   'askQty': '65.79000000',
#   'openPrice': '0.00260000',
#   'highPrice': '0.00262300',
#   'lowPrice': '0.00249500',
#   'volume': '194669.71400000',
#   'quoteVolume': '496.18795871',
#   'openTime': 1655749303545,
#   'closeTime': 1655835703545,
#   'firstId': 81298539,
#   'lastId': 81337688,
#   'count': 39150},
#  {'symbol': 'BNBBTC',
#   'priceChange': '-0.00007100',
#   'priceChangePercent': '-0.668',
#   'weightedAvgPrice': '0.01053004',
#   'prevClosePrice': '0.01062600',
#   'lastPrice': '0.01055100',
#   'lastQty': '0.73000000',
#   'bidPrice': '0.01055100',
#   'bidQty': '15.59400000',
#   'askPrice': '0.01055200',
#   'askQty': '19.89100000',
#   'openPrice': '0.01062200',
#   'highPrice': '0.01066800',
#   'lowPrice': '0.01038100',
#   'volume': '93666.51800000',
#   'quoteVolume': '986.31212529',
#   'openTime': 1655749303515,
#   'closeTime': 1655835703515,
#   'firstId': 188659639,
#   'lastId': 188727062,
#   'count': 67424}]

# %%
bnc_df = pd.DataFrame.from_dict(bnc.json())
bnc_df
# Out:
#         symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0       ETHBTC  -0.00052200             -0.954       0.05465656
# 1       LTCBTC  -0.00006900             -2.654       0.00254887
# 2       BNBBTC  -0.00007100             -0.668       0.01053004
# 3       NEOBTC  -0.00001200             -2.637       0.00044494
# 4      QTUMETH  -0.00001100             -0.438       0.00249169
# ...        ...          ...                ...              ...
# 2063   ASRBUSD   0.49600000             16.796       3.12967902
# 2064  FIROBUSD   0.04200000              2.954       1.47671772
# 2065   NKNBUSD   0.01460000             18.159       0.09701216
# 2066     OPBNB   0.00012600              5.369       0.00236684
# 2067     OPEUR   0.03700000              7.371       0.50590365
#
#      prevClosePrice   lastPrice       lastQty    bidPrice         bidQty  \
# 0        0.05473300  0.05421000    0.86750000  0.05420800     8.79830000
# 1        0.00260100  0.00253100    1.87000000  0.00253100    10.55900000
# 2        0.01062600  0.01055100    0.73000000  0.01055100    15.59400000
# 3        0.00045500  0.00044300   72.64000000  0.00044300   130.42000000
# 4        0.00252700  0.00250100    2.70000000  0.00250400    68.40000000
# ...             ...         ...           ...         ...            ...
# 2063     2.95200000  3.44900000  105.60000000  3.44400000    30.90000000
# 2064     1.41000000  1.46400000    7.00000000  1.46000000   341.40000000
# 2065     0.07950000  0.09500000  105.00000000  0.09480000  5268.00000000
# 2066     0.00235200  0.00247300   21.50000000  0.00246900   359.20000000
# 2067     0.47900000  0.53900000   36.55000000  0.52300000   316.34000000
#
#         askPrice  ...   openPrice   highPrice    lowPrice             volume  \
# 0     0.05420900  ...  0.05473200  0.05559700  0.05373800    240257.36420000
# 1     0.00253200  ...  0.00260000  0.00262300  0.00249500    194669.71400000
# 2     0.01055200  ...  0.01062200  0.01066800  0.01038100     93666.51800000
# 3     0.00044400  ...  0.00045500  0.00045600  0.00043700     54733.22000000
# 4     0.00251200  ...  0.00251200  0.00252600  0.00246600      4281.30000000
# ...          ...  ...         ...         ...         ...                ...
# 2063  3.46100000  ...  2.95300000  3.55000000  2.91000000    458811.30000000
# 2064  1.46400000  ...  1.42200000  1.56400000  1.40400000     34062.50000000
# 2065  0.09510000  ...  0.08040000  0.10790000  0.07780000  14147269.00000000
# 2066  0.00247700  ...  0.00234700  0.00253200  0.00227900     40729.90000000
# 2067  0.52800000  ...  0.50200000  0.55300000  0.45700000     28908.83000000
#
#            quoteVolume       openTime      closeTime    firstId     lastId  \
# 0       13131.64058701  1655749304179  1655835704179  350183160  350451842
# 1         496.18795871  1655749303545  1655835703545   81298539   81337688
# 2         986.31212529  1655749303515  1655835703515  188659639  188727062
# 3          24.35306430  1655749304014  1655835704014   43596542   43600599
# 4          10.66767670  1655749291052  1655835691052    5291446    5291754
# ...                ...            ...            ...        ...        ...
# 2063  1435932.09870000  1655749302835  1655835702835     362769     367813
# 2064    50300.69720000  1655749275108  1655835675108       2785       3266
# 2065  1372457.12350000  1655749300539  1655835700539      37948      43873
# 2066       96.40121050  1655749303846  1655835703846       1208       1788
# 2067    14625.08256000  1655749303894  1655835703894        352        466
#
#        count
# 0     268683
# 1      39150
# 2      67424
# 3       4058
# 4        309
# ...      ...
# 2063    5045
# 2064     482
# 2065    5926
# 2066     581
# 2067     115
#
# [2068 rows x 21 columns]

# %%
bnc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068 entries, 0 to 2067
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symbol              2068 non-null   object
#  1   priceChange         2068 non-null   object
#  2   priceChangePercent  2068 non-null   object
#  3   weightedAvgPrice    2068 non-null   object
#  4   prevClosePrice      2068 non-null   object
#  5   lastPrice           2068 non-null   object
#  6   lastQty             2068 non-null   object
#  7   bidPrice            2068 non-null   object
#  8   bidQty              2068 non-null   object
#  9   askPrice            2068 non-null   object
#  10  askQty              2068 non-null   object
#  11  openPrice           2068 non-null   object
#  12  highPrice           2068 non-null   object
#  13  lowPrice            2068 non-null   object
#  14  volume              2068 non-null   object
#  15  quoteVolume         2068 non-null   object
#  16  openTime            2068 non-null   int64
#  17  closeTime           2068 non-null   int64
#  18  firstId             2068 non-null   int64
#  19  lastId              2068 non-null   int64
#  20  count               2068 non-null   int64
# dtypes: int64(5), object(16)
# memory usage: 339.4+ KB

# %%
bnc_df['priceChangePercent'] = pd.to_numeric(bnc_df['priceChangePercent'])

# %%
bnc_df_top25 = bnc_df.sort_values('priceChangePercent', ascending=False).head(25)
bnc_df_top25.head()
# Out:
#          symbol  priceChange  priceChangePercent weightedAvgPrice  \
# 2004   WAVESTRY  37.50000000              45.956     108.71068507
# 435   WAVESUSDT   2.15000000              45.940       6.07493784
# 727   WAVESBUSD   2.15000000              45.940       6.20171483
# 1976   WAVESEUR   2.00000000              44.743       5.63764943
# 195    WAVESETH   0.00169800              39.840       0.00540205
#
#      prevClosePrice     lastPrice       lastQty      bidPrice         bidQty  \
# 2004    81.60000000  119.10000000  295.06300000  119.00000000    75.00000000
# 435      4.68000000    6.83000000  211.82000000    6.83000000  2298.72000000
# 727      4.67000000    6.83000000  454.90000000    6.82000000   691.61000000
# 1976     4.43000000    6.47000000   19.24000000    6.48000000    29.29000000
# 195      0.00428200    0.00596000   26.92000000    0.00593300    70.62000000
#
#           askPrice  ...    openPrice     highPrice     lowPrice  \
# 2004  119.10000000  ...  81.60000000  125.00000000  80.50000000
# 435     6.84000000  ...   4.68000000    7.20000000   4.61000000
# 727     6.83000000  ...   4.68000000    7.19000000   4.62000000
# 1976    6.50000000  ...   4.47000000    6.81000000   4.41000000
# 195     0.00595900  ...   0.00426200    0.00616100   0.00421700
#
#                  volume         quoteVolume       openTime      closeTime  \
# 2004   3533443.54700000  384123068.63960000  1655749304092  1655835704092
# 435   20767109.77000000  126158900.89960000  1655749304188  1655835704188
# 727    5345404.39000000   33150673.66290000  1655749304110  1655835704110
# 1976     94492.67000000     532716.54710000  1655749304190  1655835704190
# 195      98381.65000000        531.46269779  1655749304272  1655835704272
#
#        firstId    lastId   count
# 2004    849442    916989   67548
# 435   69461782  69729927  268146
# 727    7213533   7302376   88844
# 1976     97241    100177    2937
# 195    5410081   5414583    4503
#
# [5 rows x 21 columns]

# %%
sns.barplot(x='priceChangePercent',
            y="symbol", 
            data=bnc_df_top25, 
            order=bnc_df_top25.symbol, 
            color='c')
# Out:
# <AxesSubplot:xlabel='priceChangePercent', ylabel='symbol'>
